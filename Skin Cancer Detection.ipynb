# %% [markdown]
# #  Skin Cancer Detection - ADHITHIA R (adhithia@gmail.com)

# %% [markdown]
# **Project Objective:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ## Bookmarks to Notebook Sections
# 1. Go to <a href=#no1>Importing all the important libraries</a><br>
# 2. Go to <a href=#no2>Data Preparation</a><br>
# &emsp;&emsp;2.1 Go to <a href=#no2.1>Train Data Set Creation</a><br>
# &emsp;&emsp;2.2 Go to <a href=#no2.2>Validation Data Set Creation</a><br>
# 3. Go to <a href=#no3>Visualizing the Data</a><br>
# 4. Go to <a href=#no4>Model 0</a><br>
# &emsp;&emsp;4.1 Go to <a href=#no4.1>Creating the Model</a><br>
# &emsp;&emsp;4.2 Go to <a href=#no4.2>Compiling the Model</a><br>
# &emsp;&emsp;4.3 Go to <a href=#no4.3>Training the Model</a><br>
# &emsp;&emsp;4.4 Go to <a href=#no4.4>Visualizing the Training Results</a><br>
# &emsp;&emsp;4.5 Go to <a href=#no4.5>Observations</a><br>
# 5. Go to <a href=#no5>Model 1</a><br>
# &emsp;&emsp;5.1 Go to <a href=#no5.1>Creating the Model</a><br>
# &emsp;&emsp;5.2 Go to <a href=#no5.2>Compiling the Model</a><br>
# &emsp;&emsp;5.3 Go to <a href=#no5.3>Training the Model</a><br>
# &emsp;&emsp;5.4 Go to <a href=#no5.4>Visualizing the Training Results</a><br>
# &emsp;&emsp;5.5 Go to <a href=#no5.5>Observations</a><br>
# 6. Go to <a href=#no6>Data Augmentation</a><br>
# &emsp;&emsp;6.1 Go to <a href=#no6.1>Specifying the Augmentation</a><br>
# &emsp;&emsp;6.2 Go to <a href=#no6.2>Visualizing the Augmented Data</a><br>
# 7. Go to <a href=#no7>Model 2</a><br>
# &emsp;&emsp;7.1 Go to <a href=#no7.1>Creating the Model</a><br>
# &emsp;&emsp;7.2 Go to <a href=#no7.2>Compiling the Model</a><br>
# &emsp;&emsp;7.3 Go to <a href=#no7.3>Training the Model</a><br>
# &emsp;&emsp;7.4 Go to <a href=#no7.4>Visualizing the Training Results</a><br>
# &emsp;&emsp;7.5 Go to <a href=#no7.5>Observations</a><br>
# 8. Go to <a href=#no8>Checking for Class Imbalance</a><br>
# 9. Go to <a href=#no9>Using Augmentor for Class Imbalance Treatment</a><br>
# &emsp;&emsp;9.1 Go to <a href=#no9.1>Installing Augmentor</a><br>
# &emsp;&emsp;9.2 Go to <a href=#no9.2>Using Augmentor</a><br>
# &emsp;&emsp;9.3 Go to <a href=#no9.3>Observations</a><br>
# 10. Go to <a href=#no10>Modelling Data using Augmentor</a><br>
# &emsp;&emsp;10.1 Go to <a href=#no10.1>Creating the Train Data Set</a><br>
# &emsp;&emsp;10.2 Go to <a href=#no10.2>Creating the Validation Data Set</a><br>
# 11. Go to <a href=#no11>Model 3</a><br>
# &emsp;&emsp;11.1 Go to <a href=#no11.1>Creating the Model</a><br>
# &emsp;&emsp;11.2 Go to <a href=#no11.2>Compiling the Model</a><br>
# &emsp;&emsp;11.3 Go to <a href=#no11.3>Training the Model</a><br>
# &emsp;&emsp;11.4 Go to <a href=#no11.4>Visualizing the Training Results</a><br>
# &emsp;&emsp;11.5 Go to <a href=#no11.5>Observations</a><br>

# %% [markdown]
# ## 1. Importing all the important libraries <a name='no1' />

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from glob import glob
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This dataset has about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
train_path="gdrive/My Drive/CNN Assignment/Train/"
test_path="gdrive/My Drive/CNN Assignment/Test/"
data_dir_train = pathlib.Path(train_path)
data_dir_test = pathlib.Path(test_path)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ## 2. Data Preparation <a name='no2' />

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %% [markdown]
# ### 2.1 Train Data Set Creation <a name='no2.1' />

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='training',
    interpolation='bilinear', follow_links=False, smart_resize=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %% [markdown]
# ### 2.2 Validation Data Set Creation <a name='no2.2' />

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='validation',
    interpolation='bilinear', follow_links=False, smart_resize=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ## 3. Visualizing the data <a name='no3' />

# %%
import matplotlib.pyplot as plt
num=0
for dirpath, dirnames, filenames in os.walk(str(train_path)):
    for filename in [f for f in filenames if f.endswith(".jpg")][:1]:
        img = PIL.Image.open(str(dirpath)+"/"+str(filename))
        plt.subplot(3,3,num+1)
        plt.title(str(dirpath).split('/')[-1])
        plt.axis('off')
        plt.imshow(img)
        num=num+1

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## 4. Model 0 <a name='no4' />

# %% [markdown]
# ### 4.1 Creating the model <a name='no4.1' />

# %%
model=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),         
    
    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),
    
    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),   
    Dense(9, activation='softmax')
])

# %% [markdown]
# ### 4.2 Compiling the model <a name='no4.2' />

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ###  4.3 Training the model <a name='no4.3' />

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 2s 36ms/step - loss: 3.9700 - accuracy: 0.1819 - val_loss: 2.0890 - val_accuracy: 0.3982
# Epoch 2/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.9418 - accuracy: 0.2907 - val_loss: 1.9838 - val_accuracy: 0.2685
# Epoch 3/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6999 - accuracy: 0.4085 - val_loss: 1.6513 - val_accuracy: 0.4407
# Epoch 4/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.5344 - accuracy: 0.4749 - val_loss: 1.5564 - val_accuracy: 0.4385
# Epoch 5/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.4492 - accuracy: 0.4916 - val_loss: 1.4024 - val_accuracy: 0.5235
# Epoch 6/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.3888 - accuracy: 0.5167 - val_loss: 1.5877 - val_accuracy: 0.4609
# Epoch 7/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.2971 - accuracy: 0.5407 - val_loss: 1.4716 - val_accuracy: 0.4832
# Epoch 8/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.2328 - accuracy: 0.5619 - val_loss: 1.4230 - val_accuracy: 0.4922
# Epoch 9/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.1631 - accuracy: 0.5904 - val_loss: 1.5640 - val_accuracy: 0.4676
# Epoch 10/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.1400 - accuracy: 0.6032 - val_loss: 1.4175 - val_accuracy: 0.5213
# Epoch 11/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.1103 - accuracy: 0.6127 - val_loss: 1.4412 - val_accuracy: 0.5168
# Epoch 12/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.9842 - accuracy: 0.6479 - val_loss: 1.4657 - val_accuracy: 0.5414
# Epoch 13/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.9186 - accuracy: 0.6775 - val_loss: 1.5148 - val_accuracy: 0.5324
# Epoch 14/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.8702 - accuracy: 0.6875 - val_loss: 1.6850 - val_accuracy: 0.5123
# Epoch 15/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.8127 - accuracy: 0.7065 - val_loss: 1.4918 - val_accuracy: 0.5369
# Epoch 16/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.7567 - accuracy: 0.7310 - val_loss: 1.6327 - val_accuracy: 0.5615
# Epoch 17/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.6754 - accuracy: 0.7578 - val_loss: 1.6532 - val_accuracy: 0.5280
# Epoch 18/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.6639 - accuracy: 0.7729 - val_loss: 1.7522 - val_accuracy: 0.4944
# Epoch 19/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.6367 - accuracy: 0.7773 - val_loss: 1.6899 - val_accuracy: 0.5459
# Epoch 20/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.6097 - accuracy: 0.7801 - val_loss: 1.6841 - val_accuracy: 0.5324

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_6 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 180, 180, 32)      896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 90, 90, 32)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 90, 90, 64)        18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 45, 45, 64)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 45, 45, 64)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 129600)            0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16588928
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 16,609,481
# Trainable params: 16,609,481
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###  4.4 Visualizing training results <a name='no4.4' />

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ###  4.5 Observations <a name='no4.5' />

# %% [markdown]
# -  The accuracy of the model for the **Training data set** is at **78%**. But the **Validation accuracy** is not in par with the training accuracy.
# -  It is only at **53%**. The validation loss as observed is very high.
# -  This could also be indicative of some **Overfit** in the model.
# -  We could add some `Dropout` layers and remove the `BatchNormalization` layers.
# -  And by adding a few more layers, we could improve the accuracy by trying to extract more features.

# %% [markdown]
# ##  5. Model 1 <a name='no5' />

# %% [markdown]
# ###  5.1 Creating the Model <a name='no5.1' />

# %%
model_update=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),         
                             
    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Conv2D(64,(3,3),activation='relu',padding='same'),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Conv2D(128,(3,3),activation='relu',padding='same'),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.25),   
    Dense(9, activation='softmax')
])

# %% [markdown]
# ### 5.2 Compiling the model <a name='no5.2' />

# %%
model_update.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics='accuracy')

# %% [markdown]
# ###  5.3 Training the model <a name='no5.3' />

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model_update.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 85ms/step - loss: 2.2128 - accuracy: 0.2059 - val_loss: 2.1205 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 5s 82ms/step - loss: 2.0545 - accuracy: 0.1903 - val_loss: 2.0521 - val_accuracy: 0.2058
# Epoch 3/20
# 56/56 [==============================] - 5s 83ms/step - loss: 2.0378 - accuracy: 0.1825 - val_loss: 2.0315 - val_accuracy: 0.2058
# Epoch 4/20
# 56/56 [==============================] - 5s 83ms/step - loss: 2.0308 - accuracy: 0.2126 - val_loss: 2.0304 - val_accuracy: 0.1924
# Epoch 5/20
# 56/56 [==============================] - 5s 83ms/step - loss: 2.0141 - accuracy: 0.2215 - val_loss: 2.0197 - val_accuracy: 0.2282
# Epoch 6/20
# 56/56 [==============================] - 5s 83ms/step - loss: 1.9918 - accuracy: 0.2288 - val_loss: 1.8931 - val_accuracy: 0.2998
# Epoch 7/20
# 56/56 [==============================] - 5s 83ms/step - loss: 1.9114 - accuracy: 0.2623 - val_loss: 1.9125 - val_accuracy: 0.2685
# Epoch 8/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.9085 - accuracy: 0.2779 - val_loss: 1.8204 - val_accuracy: 0.3423
# Epoch 9/20
# 56/56 [==============================] - 5s 83ms/step - loss: 1.8329 - accuracy: 0.3041 - val_loss: 1.7795 - val_accuracy: 0.3423
# Epoch 10/20
# 56/56 [==============================] - 5s 83ms/step - loss: 1.8032 - accuracy: 0.3225 - val_loss: 1.7327 - val_accuracy: 0.3870
# Epoch 11/20
# 56/56 [==============================] - 5s 82ms/step - loss: 1.7144 - accuracy: 0.3566 - val_loss: 1.6790 - val_accuracy: 0.3803
# Epoch 12/20
# 56/56 [==============================] - 5s 82ms/step - loss: 1.6599 - accuracy: 0.3895 - val_loss: 1.6588 - val_accuracy: 0.3758
# Epoch 13/20
# 56/56 [==============================] - 5s 82ms/step - loss: 1.6840 - accuracy: 0.3834 - val_loss: 1.7022 - val_accuracy: 0.3669
# Epoch 14/20
# 56/56 [==============================] - 5s 81ms/step - loss: 1.6433 - accuracy: 0.4012 - val_loss: 1.6095 - val_accuracy: 0.3893
# Epoch 15/20
# 56/56 [==============================] - 5s 81ms/step - loss: 1.6026 - accuracy: 0.4152 - val_loss: 1.5734 - val_accuracy: 0.4541
# Epoch 16/20
# 56/56 [==============================] - 5s 81ms/step - loss: 1.6143 - accuracy: 0.4180 - val_loss: 1.5570 - val_accuracy: 0.4564
# Epoch 17/20
# 56/56 [==============================] - 5s 81ms/step - loss: 1.5816 - accuracy: 0.4241 - val_loss: 1.8365 - val_accuracy: 0.3244
# Epoch 18/20
# 56/56 [==============================] - 5s 81ms/step - loss: 1.5814 - accuracy: 0.4258 - val_loss: 1.7631 - val_accuracy: 0.3468
# Epoch 19/20
# 56/56 [==============================] - 5s 82ms/step - loss: 1.6614 - accuracy: 0.4029 - val_loss: 1.6445 - val_accuracy: 0.3982
# Epoch 20/20
# 56/56 [==============================] - 5s 82ms/step - loss: 1.5501 - accuracy: 0.4263 - val_loss: 1.6423 - val_accuracy: 0.3826

# %% [markdown]
# ###  5.4 Visualizing the results <a name='no5.4' />

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ###  5.5 Observations <a name='no5.5' />

# %% [markdown]
# -  The model accuracy for **Train data set** has dropped to nearly **45%**.
# -  The accuracy for the **Validation set** is at **40%**.
# -  This is a much better model compared to the previous model as there seems to be **No Overfit** with the training accuracy **45%** and validation accuracy at **40%**.

# %% [markdown]
# ##  6. Data Augmentation <a name='no6' />

# %% [markdown]
# ###  6.1 Specifying the Augmentation <a name='no6.1' />

# %%
data_augmentation=tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2)
])

# %% [markdown]
# ###  6.2 Visualizing the Augmented Data <a name='no6.2' />

# %%
image, label = next(iter(train_ds))
image=np.array(image,np.int32)  
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(3, 3, i + 1)
  augmented_image1=np.array(augmented_image[0],np.int32)  
  plt.imshow((augmented_image1))
  plt.axis("off")

# %% [markdown]
# ## 7. Model 2 <a name='no7' />

# %% [markdown]
# ###  7.1 Creating the Model <a name='no7.1' />

# %%
model_augmented=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),         

    data_augmentation,

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Conv2D(64,(3,3),activation='relu',padding='same'),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Conv2D(128,(3,3),activation='relu',padding='same'),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.25),   
    Dense(9, activation='softmax')
])

# %% [markdown]
# ### 7.2 Compiling the model <a name='no7.2' />

# %%
model_augmented.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics='accuracy')

# %% [markdown]
# ### 7.3 Training the model <a name='no7.3' />

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model_augmented.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 87ms/step - loss: 2.1868 - accuracy: 0.1881 - val_loss: 2.0423 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 5s 84ms/step - loss: 2.0349 - accuracy: 0.2003 - val_loss: 2.0339 - val_accuracy: 0.2058
# Epoch 3/20
# 56/56 [==============================] - 5s 84ms/step - loss: 2.0370 - accuracy: 0.1948 - val_loss: 2.0275 - val_accuracy: 0.1924
# Epoch 4/20
# 56/56 [==============================] - 5s 84ms/step - loss: 2.0267 - accuracy: 0.2015 - val_loss: 2.0258 - val_accuracy: 0.2058
# Epoch 5/20
# 56/56 [==============================] - 5s 84ms/step - loss: 2.0249 - accuracy: 0.2137 - val_loss: 2.0275 - val_accuracy: 0.2058
# Epoch 6/20
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0268 - accuracy: 0.1970 - val_loss: 2.0237 - val_accuracy: 0.1924
# Epoch 7/20
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0240 - accuracy: 0.2020 - val_loss: 2.0256 - val_accuracy: 0.1924
# Epoch 8/20
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0278 - accuracy: 0.1981 - val_loss: 2.0224 - val_accuracy: 0.1924
# Epoch 9/20
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0197 - accuracy: 0.2026 - val_loss: 2.0235 - val_accuracy: 0.1924
# Epoch 10/20
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0183 - accuracy: 0.2093 - val_loss: 2.0167 - val_accuracy: 0.1924
# Epoch 11/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.9963 - accuracy: 0.2188 - val_loss: 2.0208 - val_accuracy: 0.1946
# Epoch 12/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.9199 - accuracy: 0.2729 - val_loss: 1.8949 - val_accuracy: 0.2573
# Epoch 13/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.7937 - accuracy: 0.3465 - val_loss: 1.7561 - val_accuracy: 0.3221
# Epoch 14/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.7133 - accuracy: 0.3845 - val_loss: 1.7606 - val_accuracy: 0.3333
# Epoch 15/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.6835 - accuracy: 0.3783 - val_loss: 1.7372 - val_accuracy: 0.3378
# Epoch 16/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.6331 - accuracy: 0.4102 - val_loss: 1.5658 - val_accuracy: 0.4161
# Epoch 17/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.6038 - accuracy: 0.4314 - val_loss: 1.7284 - val_accuracy: 0.4072
# Epoch 18/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.5452 - accuracy: 0.4498 - val_loss: 1.7031 - val_accuracy: 0.3826
# Epoch 19/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.5329 - accuracy: 0.4498 - val_loss: 1.6088 - val_accuracy: 0.4228
# Epoch 20/20
# 56/56 [==============================] - 5s 84ms/step - loss: 1.5068 - accuracy: 0.4710 - val_loss: 1.4872 - val_accuracy: 0.4765

# %% [markdown]
# ### 7.4 Visualizing the results <a name='no7.4' />

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### 7.5  Observations <a name='no7.5' />

# %% [markdown]
# -  The model accuracy for **Train data set** has gone up to nearly **48%**.
# -  The accuracy for the **Validation set** is also at **48%**.
# -  This is a much better model compared to the previous two models as there seems to be **No Overfit** with the training accuracy **48%** and validation accuracy at **48%**.
# -  `Data Augmentation` has improved the model performance.

# %% [markdown]
# ## 8. Checking for Class Imbalance <a name='no8' />

# %%
for i in class_names:
    directory =train_path+i+'/'
    class_directory = pathlib.Path(directory)
    length=len(list(class_directory.glob('*.jpg')))
    print(f'{i} has {length} samples.')
# Out:
# actinic keratosis has 114 samples.
# basal cell carcinoma has 376 samples.
# dermatofibroma has 95 samples.
# melanoma has 438 samples.
# nevus has 357 samples.
# pigmented benign keratosis has 462 samples.
# seborrheic keratosis has 77 samples.
# squamous cell carcinoma has 181 samples.
# vascular lesion has 139 samples.

# %% [markdown]
# -  The samples of various classes are not in equal proportion.
# -  There is a significant **Class Imbalance** observed.
# -  The class with the least number of samples is `Seborrheic Keratosis` with **77**.
# -  The class that dominates the data in terms of proportionate number of samples is `Pigmented Benign Keratosis` with sample size of **462**.

# %% [markdown]
# ## 9. Using Augmentor for Class Imbalance Treatment <a name='no9' />

# %% [markdown]
# ###  9.1 Installing Augmentor <a name='no9.1' />

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.8)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.19.5)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.41.1)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %% [markdown]
# ### 9.2 Using Augmentor <a name='no9.2' />

# %%
path_to_training_dataset=train_path
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 114 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F27DC17DE10>: 100%|██████████| 500/500 [00:18<00:00, 27.24 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F27DC033D90>:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F27DC0B0650>: 100%|██████████| 500/500 [00:18<00:00, 27.45 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F27DC160810>: 100%|██████████| 500/500 [00:19<00:00, 26.26 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F27DC1DDE90>: 100%|██████████| 500/500 [01:12<00:00,  6.87 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7F27DC105ED0>: 100%|██████████| 500/500 [01:23<00:00,  5.98 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F283B32FA90>: 100%|██████████| 500/500 [00:19<00:00, 26.10 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F27DC078C10>: 100%|██████████| 500/500 [00:40<00:00, 12.24 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F27DC1E7FD0>: 100%|██████████| 500/500 [00:19<00:00, 25.03 Samples/s]
# Executing Pipeline:   0%|          | 0/500 [00:00<?, ? Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/My Drive/CNN Assignment/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F27DC59C3D0>: 100%|██████████| 500/500 [00:19<00:00, 25.23 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
for i in class_names:
    directory =train_path+i+'/'
    directory_out =train_path+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob('*.jpg')))
    length_out=len(list(class_directory_out.glob('*.jpg')))
    length_tot=length+length_out
    print(f'{i} has {length_tot} samples.')
# Out:
# actinic keratosis has 614 samples.
# basal cell carcinoma has 876 samples.
# dermatofibroma has 595 samples.
# melanoma has 938 samples.
# nevus has 857 samples.
# pigmented benign keratosis has 962 samples.
# seborrheic keratosis has 577 samples.
# squamous cell carcinoma has 681 samples.
# vascular lesion has 639 samples.

# %% [markdown]
# ### 9.3 Observations <a name='no9.3' />

# %% [markdown]
# -  The Augmentor has **helped decrease the imbalance** in class images and that can be viewed from above.

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ##  10. Modelling Augmented Data <a name='no10' />

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ### 10.1 Creating the Train Data Set <a name='no10.1' />

# %%
data_dir_train=train_path
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ### 10.2 Creating the Validation Data Set <a name='no10.2' />

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ## 11. Model 3 <a name='no11' />

# %% [markdown]
# ### 11.1 Creating the Model <a name='no11.1' />

# %%
model_final=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),         
    
    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),
    
    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),   
    Dense(9, activation='softmax')
])

# %% [markdown]
# ### 11.2 Compiling the Model <a name='no11.2' />

# %%
model_final.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics='accuracy')

# %% [markdown]
# ### 11.3 Training the Model <a name='no11.3' />

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model_final.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 33s 188ms/step - loss: 2.4392 - accuracy: 0.2127 - val_loss: 1.8045 - val_accuracy: 0.3526
# Epoch 2/30
# 169/169 [==============================] - 32s 186ms/step - loss: 1.6090 - accuracy: 0.3858 - val_loss: 1.4856 - val_accuracy: 0.4380
# Epoch 3/30
# 169/169 [==============================] - 32s 185ms/step - loss: 1.4185 - accuracy: 0.4713 - val_loss: 1.3111 - val_accuracy: 0.5011
# Epoch 4/30
# 169/169 [==============================] - 32s 187ms/step - loss: 1.2884 - accuracy: 0.5185 - val_loss: 1.1714 - val_accuracy: 0.5805
# Epoch 5/30
# 169/169 [==============================] - 32s 185ms/step - loss: 1.1175 - accuracy: 0.5885 - val_loss: 1.1704 - val_accuracy: 0.5768
# Epoch 6/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.9862 - accuracy: 0.6415 - val_loss: 1.0150 - val_accuracy: 0.6325
# Epoch 7/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.8684 - accuracy: 0.6793 - val_loss: 1.0901 - val_accuracy: 0.6266
# Epoch 8/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.7888 - accuracy: 0.7144 - val_loss: 0.8880 - val_accuracy: 0.6800
# Epoch 9/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.6687 - accuracy: 0.7576 - val_loss: 0.8949 - val_accuracy: 0.6830
# Epoch 10/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.5911 - accuracy: 0.7862 - val_loss: 0.8008 - val_accuracy: 0.7446
# Epoch 11/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.5198 - accuracy: 0.8080 - val_loss: 0.8142 - val_accuracy: 0.7409
# Epoch 12/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.4767 - accuracy: 0.8264 - val_loss: 0.7828 - val_accuracy: 0.7543
# Epoch 13/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.4215 - accuracy: 0.8477 - val_loss: 0.8137 - val_accuracy: 0.7520
# Epoch 14/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.3774 - accuracy: 0.8616 - val_loss: 0.7829 - val_accuracy: 0.7728
# Epoch 15/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.3571 - accuracy: 0.8722 - val_loss: 0.8294 - val_accuracy: 0.7550
# Epoch 16/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.3062 - accuracy: 0.8891 - val_loss: 0.7763 - val_accuracy: 0.7877
# Epoch 17/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.3107 - accuracy: 0.8865 - val_loss: 0.8199 - val_accuracy: 0.7765
# Epoch 18/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.3089 - accuracy: 0.8835 - val_loss: 0.8380 - val_accuracy: 0.7869
# Epoch 19/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2609 - accuracy: 0.9021 - val_loss: 0.8477 - val_accuracy: 0.7847
# Epoch 20/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2313 - accuracy: 0.9115 - val_loss: 0.9751 - val_accuracy: 0.7825
# Epoch 21/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2386 - accuracy: 0.9088 - val_loss: 0.8946 - val_accuracy: 0.7758
# Epoch 22/30
# 169/169 [==============================] - 32s 183ms/step - loss: 0.2353 - accuracy: 0.9145 - val_loss: 0.9980 - val_accuracy: 0.7728
# Epoch 23/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.2231 - accuracy: 0.9173 - val_loss: 0.9417 - val_accuracy: 0.8010
# Epoch 24/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2256 - accuracy: 0.9160 - val_loss: 0.9272 - val_accuracy: 0.7758
# Epoch 25/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2166 - accuracy: 0.9227 - val_loss: 0.9089 - val_accuracy: 0.7639
# Epoch 26/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.2138 - accuracy: 0.9193 - val_loss: 0.9949 - val_accuracy: 0.7728
# Epoch 27/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.1970 - accuracy: 0.9204 - val_loss: 1.0302 - val_accuracy: 0.7869
# Epoch 28/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.1723 - accuracy: 0.9336 - val_loss: 1.1085 - val_accuracy: 0.7758
# Epoch 29/30
# 169/169 [==============================] - 32s 185ms/step - loss: 0.1870 - accuracy: 0.9253 - val_loss: 1.1292 - val_accuracy: 0.7825
# Epoch 30/30
# 169/169 [==============================] - 32s 184ms/step - loss: 0.1885 - accuracy: 0.9318 - val_loss: 1.1332 - val_accuracy: 0.7773

# %% [markdown]
# ###  11.4 Visualizing the model results <a name='no11.4' />

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### 11.5 Observations <a name='no11.5' />

# %% [markdown]
# -  The training accuracy seems to be nearly **~90%**.
# -  The validation accuracy is nearly **~80%**.
# -  Though the model accuracy has improved, the **class rebalance** has helped **treat the overfitting to some extent**.
# -  Much better models could be built or tried out using **more epochs and more layers**.
